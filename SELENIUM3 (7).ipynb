# %%
import selenium
import pandas as pd
from selenium import webdriver
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException, ElementNotInteractableException
from bs4 import BeautifulSoup
import requests
import re

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# %% [markdown]
# # 1.

# %%
url = "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/"
driver.get(url)

# %%
search_button = driver.find_element_by_xpath('//a[@class="external text"]')       
search_button.click()

# %%
search = driver.find_element_by_xpath('//a[@title="List of most-viewed YouTube videos"]')       
search.click()

# %%
Rank=[]
Name=[]
Artist=[]
Upload_date=[]
Views=[]

# %%
rank=[]
for i in driver.find_elements_by_xpath("//td[@align='center']"):
    rank.append(i.text)

# %%
name=[]
for i in driver.find_elements_by_xpath("//a[@class='mw-redirect']"):
    name.append(i.text)

# %%
artist=[]
for i in driver.find_elements_by_xpath("//a[@title='Pinkfong']"):
    artist.append(i.text)

# %%
date=[]
for i in driver.find_elements_by_xpath("//td[@align='right']"):
    date.append(i.text)

# %%
view=[]
for i in driver.find_elements_by_xpath("//td[@align='center']"):
        view.append(i.text)

# %%
a=({'Rank':rank,
                     'Name':name,
                     'Upload_date':date,
                     'Artist':artist,
                     'Views':view})

# %%
df = pd.DataFrame.from_dict(a, orient='index')
df = df.transpose()

# %%
df.head(10)
# Out:
#    Rank                        Name        Upload_date  \
# 0    1.                music videos      June 17, 2016
# 1  9.00            Baby Shark Dance   January 12, 2017
# 2   [B]            Baby Shark Dance    October 8, 2016
# 3    2.            Baby Shark Dance   January 30, 2017
# 4  7.45  Cocomelon – Nursery Rhymes      April 6, 2015
# 5   [C]  Cocomelon – Nursery Rhymes   January 31, 2012
# 6    3.  Cocomelon – Nursery Rhymes        May 2, 2018
# 7  5.56         The Gummy Bear Song  February 27, 2018
# 8   [D]             Fueled By Ramen  November 19, 2014
# 9    4.         The Gummy Bear Song      July 15, 2012
#
#                            Artist Views
# 0                        Pinkfong    1.
# 1  Pinkfong Kids' Songs & Stories  9.00
# 2                        Pinkfong   [B]
# 3                        Pinkfong    2.
# 4                            None  7.45
# 5                            None   [C]
# 6                            None    3.
# ...

# %% [markdown]
# # 2.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# %%
url = "https://www.bcci.tv/"
driver.get(url)

# %%
international = driver.find_element_by_xpath('//div[@class="navigation__drop-down drop-down drop-down--reveal-on-hover"]')       
international.click()

# %%
fixtures = driver.find_element_by_xpath('/html/body/div[3]/div/div[2]/div[2]/nav/ul/li[1]/div[2]/div/ul/li[1]/a')
fixtures.click()

# %%
rank = []
for i in driver.find_elements_by_xpath('//strong[@class="fixture__name fixture__name--with-margin"]'):
    rank.append(i.text)

# %%
date = []
for i in driver.find_elements_by_xpath('//span[@class="fixture__date"]'):
    date.append(i.text)

# %%
month = []
for i in driver.find_elements_by_xpath('//span[@class="fixture__month"]'):
    month.append(i.text)

# %%
time = []
for i in driver.find_elements_by_xpath('//span[@class="fixture__time"]'):
    time.append(i.text)

# %%
series = []
for i in driver.find_elements_by_xpath('//div[@class="fixture__teams"]'):
    series.append(i.text)

# %%
df = pd.DataFrame({'Rank':rank,'Date':date,'Month':month,'Time':time,'Series':series})

# %%
df
# Out:
#        Rank Date      Month       Time               Series
# 0   3rd ODI   23       JULY  15:00 IST  SRI LANKA\nv\nINDIA
# 1  1st T20I   25       JULY  20:00 IST  SRI LANKA\nv\nINDIA
# 2  2nd T20I   27       JULY  20:00 IST  SRI LANKA\nv\nINDIA
# 3  3rd T20I   29       JULY  20:00 IST  SRI LANKA\nv\nINDIA
# 4  1st Test   04     AUGUST  15:30 IST    ENGLAND\nv\nINDIA
# 5  2nd Test   12     AUGUST  15:30 IST    ENGLAND\nv\nINDIA
# 6  3rd Test   25     AUGUST  15:30 IST    ENGLAND\nv\nINDIA
# 7  4th Test   02  SEPTEMBER  15:30 IST    ENGLAND\nv\nINDIA
# 8  5th Test   10  SEPTEMBER  15:30 IST    ENGLAND\nv\nINDIA

# %% [markdown]
# # 3.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# %%
url = "https://www.guru99.com/exception-handling-selenium.html"
driver.get(url)

# %%
name=[]
for i in driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr[2]/td[1]"):
    name.append(i.text)

# %%
name
# Out:
# ['ElementNotVisibleException']

# %%
desc=[]
for i in driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr[2]/td[2]"):
    desc.append(i.text)

# %%
desc
# Out:
# ['This type of Selenium exception occurs when an existing element in DOM has a feature set as hidden.']

# %%
df=pd.DataFrame({'Name':name, 'description':desc})

# %%
df
# Out:
#                          Name  \
# 0  ElementNotVisibleException
#
#                                          description
# 0  This type of Selenium exception occurs when an...

# %% [markdown]
# # 4.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# %%
url = "http://statisticstimes.com/"
driver.get(url)

# %%
economy = driver.find_element_by_xpath('//button[@class="dropbtn"]')       
economy.click()

# %%
gdp = driver.find_element_by_xpath('//a[@class="ec"]')       
gdp.click()

# %%
rank=[]
for i in driver.find_elements_by_xpath("//td[@class='data1']"):
    rank.append(i.text)

# %%
state=[]
for i in driver.find_elements_by_xpath("//td[@class='name']"):
    state.append(i.text)

# %%
gsdp1=[]
for i in driver.find_elements_by_xpath("td[@class='data']"):
    gsdp1.append(i.text)

# %%
gsdp2=[]
for i in driver.find_elements_by_xpath("//td[@class='data sorting_1']"):
    gsdp2.append(i.text)

# %%
share=[]
for i in driver.find_elements_by_xpath("//td[@class='data']"):
    share.append(i.text)

# %%
gdp=[]
for i in driver.find_elements_by_xpath("//td[@class='data']"):
    gdp.append(i.text)

# %%
a=({'Rank':rank, 'State':state, 'Gsdp19-20':gsdp1, 'Gsdp18-19':gsdp2, 'Share':share, 'GDP':gdp})

# %%
df=pd.DataFrame.from_dict(a,orient='index')
df= df.transpose()

# %%
df
# Out:
#      Rank          State Gsdp19-20  Gsdp18-19       Share         GDP
# 0       1    Maharashtra      None  2,632,792           -           -
# 1       2     Tamil Nadu      None  1,630,208      13.94%      13.94%
# 2       3  Uttar Pradesh      None  1,584,764     399.921     399.921
# 3       4        Gujarat      None  1,502,899           -           -
# 4       5      Karnataka      None  1,493,127   2,039,074   2,039,074
# ..    ...            ...       ...        ...         ...         ...
# 303  None           None      None       None  17,994,301  17,994,301
# 304  None           None      None       None  16,704,645  16,704,645
# 305  None           None      None       None
# 306  None           None      None       None  12,681,246  12,681,246
# 307  None           None      None       None  12,240,380  12,240,380
#
# [308 rows x 6 columns]

# %% [markdown]
# # 5.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# %%
url = "https://github.com/"
driver.get(url)

# %%
search = driver.find_element_by_xpath("//input[@class='form-control input-sm header-search-input jump-to-field js-jump-to-field js-site-search-focus']")
search
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="7cba5ca9952e70c20d98d5fc3f960cf5", element="44122fc8-816b-4b39-8293-4d8db0e5d876")>

# %%
search.send_keys('trending')

# %%
search1= driver.find_element_by_xpath('//span[@class="js-jump-to-badge-search-text-global"]')       
search1.click()

# %%
title=[]
for i in driver.find_elements_by_xpath("//div[@class='f4 text-normal']"):
    title.append(i.text)

# %%
desc=[]
for i in driver.find_elements_by_xpath("//p[@class='mb-1']"):
    desc.append(i.text)

# %%
count=[]
for i in driver.find_elements_by_xpath("//a[@class='Link--muted']"):
    count.append(i.text)

# %%
lang=[]
for i in driver.find_elements_by_xpath("//span[@itemprop='programmingLanguage']"):
    lang.append(i.text)

# %%
a=({'respository_title':title, 'repository_description':desc, 'contributor_count':count, 'language':lang})

# %%
df=pd.DataFrame.from_dict(a,orient='index')
df= df.transpose()

# %%
df
# Out:
#                 respository_title  \
# 0   iam-abbas/Reddit-Stock-Trends
# 1  mbadry1/Trending-Deep-Learning
# 2    datawrangling/trendingtopics
# 3  vitalets/github-trending-repos
# 4           GeneralMills/pytrends
# 5                           d3/d3
# 6    huchenme/github-trending-api
# 7          rnoelle/trendingTrivia
# 8          Nightonke/GithubWidget
# 9                 ophobe/trending
#
#                               repository_description contributor_count  \
# 0          Fetch currently trending stocks on Reddit              1.5k
# 1  Top 100 trending deep learning repositories so...               553
# 2  Rails app for tracking trends in server logs -...               352
# 3  Track GitHub trending repositories in your fav...              2.2k
# 4                       Pseudo API for Google Trends              2.1k
# 5  Bring data to life with SVG, Canvas and HTML. ...             97.6k
# 6  The missing APIs for GitHub trending projects ...               648
# ...

# %% [markdown]
# # 6.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# %%
url = "https://www.billboard.com/"
driver.get(url)

# %%
hot100 = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/nav/ul/li[3]/a')
hot100.click()

# %%
name=[]
for i in driver.find_elements_by_xpath("//span[@class='chart-element__information__song text--truncate color--primary']"):
    name.append(i.text)

# %%
artist=[]
for i in driver.find_elements_by_xpath("//span[@class='chart-element__information__artist text--truncate color--secondary']"):
    name.append(i.text)

# %%
lwrank=[]
for i in driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']"):
    lwrank.append(i.text)

# %%
prank=[]
for i in driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']"):
    prank.append(i.text)

# %%
board=[]
for i in driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--week']"):
    board.append(i.text)

# %%
a=({'Song_name':name,
'Artist_name':artist,
'Last_week_rank':lwrank,
'Peak_rank':prank,
'Weeks_on_board':board})

# %%
df=pd.DataFrame.from_dict(a,orient='index')
df= df.transpose()

# %%
df
# Out:
#                         Song_name Artist_name Last_week_rank Peak_rank  \
# 0             Permission To Dance        None              -         1
# 1                        Good 4 U        None              2         1
# 2                            Stay        None              -         3
# 3                      Levitating        None              3         2
# 4                    Kiss Me More        None              4         3
# ..                            ...         ...            ...       ...
# 195  Brent Faiyaz Featuring Drake        None           None      None
# 196                          P!nk        None           None      None
# 197       MO3 X OG Bobby Billions        None           None      None
# 198  Trippie Redd & Playboi Carti        None           None      None
# 199                  Carly Pearce        None           None      None
#
#     Weeks_on_board
# 0                1
# 1                9
# 2                1
# 3               41
# ...

# %% [markdown]
# # 7.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# %%
url = "https://www.naukri.com/"
driver.get(url)

# %%
recruiters=driver.find_element_by_xpath("//a[@title='Search Recruiters']")
driver.get(recruiters.get_attribute('href'))
time.sleep(1)

# %%
search=driver.find_element_by_xpath("//input[@class='sugInp']")
search.send_keys("Data Science")
time.sleep(1)

# %%
button=driver.find_element_by_xpath("//button[@id='qsbFormBtn']")
button.click()
time.sleep(1)

# %%
name=[]
try:
    names=driver.find_elements_by_xpath("//div[@class='recInfo']/div/p/a[1]")
    for i in names:
        name.append(i.text)
except NoSuchElementException:           #handling no such element exception
    name.append('No details available')
time.sleep(2)

# %%
designation=[]
try:
    designation_list=driver.find_elements_by_xpath("//div[@class='recInfo']/div/p/span[1]")
    for i in designation_list:
        designation.append(i.text)
except NoSuchElementException:        #handling no such element exception
    designation.append('No details available')
time.sleep(2)

# %%
company=[]
try:
    companies=driver.find_elements_by_xpath("//div[@class='recInfo']/div/p/a[2]")
    for i in companies:
        company.append(i.text)
except NoSuchElementException:#handling no such element exception
    company.append('No details available')
time.sleep(2)

# %%
location=[]
soup=BeautifulSoup(driver.page_source,'html.parser')
l=soup.find_all('div',attrs={'vcard'})
for i in l:
    try:
        location.append(i.find('small').text)
    except AttributeError :
        location.append("No details available")
time.sleep(2)

# %%
skill=[]
try:
    skills=driver.find_elements_by_xpath("//div[@class='recInfo']/div[2]")
    for i in skills:
        skill.append(i.text)
except NoSuchElementException:        #handling no such element exception
    skill.append('No details available')
time.sleep(2)

# %%
df=pd.DataFrame({'Name':name,
                'Designation':designation,
                'Company':company,
                "Location":location,
                'Skills I hire':skill})

# %%
df
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                Kalpana Dumpala
# 11                                        Mubarak
# 12                                 Kushal Rastogi
# 13                                    Ruchi Dhote
# 14                             Mahesh Babu Channa
# 15                                   Kapil Devang
# 16                                  Manisha Yadav
# 17                                    Riya Rajesh
# ...

# %% [markdown]
# # 8.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# %%
url = "https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/"
driver.get(url)

# %%
name=[]
for i in driver.find_elements_by_xpath("//h2[@class='pb-right__block__standfirst show-desktop']"):
    name.append(i.text)

# %%
name
# Out:
# ["A scathing takedown of 'Uncle Donald'",
#  'Coe’s love letter to the spirit of cinema',
#  'Meticulously plotted',
#  'Inside the extraordinary world of moss',
#  'An extravagant, unnerving fantasy',
#  'An astonishing novel set in Ferrante’s familiar Naples',
#  'A fizzing New York fantasy',
#  'A dark, explosive follow-up to Convenience Store Woman',
#  'The larky, and moving, follow-up to How to Be a Woman',
#  'A wise memoir about tragedy and family',
#  'Candid account of a Tory clique',
#  'Witty debut novel from the popular podcaster',
#  'Entertaining eco-thriller',
#  "A woman's life in 19th-century Japan",
#  'Post-9/11 America through the eyes of a Muslim and his father',
#  "Reclaiming Australia's Indigenous voices",
#  'A fascinating and overlooked history',
#  'Coming of age in Uganda',
#  'How sharks are misunderstood',
#  'Rollicking fantasy set in an alternate 1980s London']

# %%
author=[]
for i in driver.find_elements_by_xpath("//h2[@class='pb-right__block__title show-desktop']"):
    author.append(i.text)

# %%
publisher=[]
for i in driver.find_elements_by_xpath("//p[@class='pb-right__block__byline']"):
    publisher.append(i.text)

# %%
sold=[]
for i in driver.find_elements_by_xpath("//a[@data-link-name='best of month : bookshop link']"):
    sold.append(i.text)

# %%
df=pd.DataFrame({'book_name':name, 'author_name':author, 'Publisher':publisher, 'Sold':sold})

# %%
df
# Out:
#                                             book_name  \
# 0               A scathing takedown of 'Uncle Donald'
# 1           Coe’s love letter to the spirit of cinema
# 2                                Meticulously plotted
# 3              Inside the extraordinary world of moss
# 4                   An extravagant, unnerving fantasy
# 5   An astonishing novel set in Ferrante’s familia...
# 6                          A fizzing New York fantasy
# 7   A dark, explosive follow-up to Convenience Sto...
# 8   The larky, and moving, follow-up to How to Be ...
# 9              A wise memoir about tragedy and family
# 10                    Candid account of a Tory clique
# 11       Witty debut novel from the popular podcaster
# 12                          Entertaining eco-thriller
# 13               A woman's life in 19th-century Japan
# 14  Post-9/11 America through the eyes of a Muslim...
# 15           Reclaiming Australia's Indigenous voices
# ...

# %% [markdown]
# # 9.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# %%
url='https://www.imdb.com/list/ls095964455/'
driver.get(url)

# %%
name=[]
for i in driver.find_elements_by_xpath("//h3[@class='lister-item-header']"):
    name.append(i.text)

# %%
span=[]
for i in driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']"):
    span.append(i.text)

# %%
genre=[]
for i in driver.find_elements_by_xpath("//span[@class='genre']"):
    genre.append(i.text)

# %%
time=[]
for i in driver.find_elements_by_xpath("//span[@class='runtime']"):
    time.append(i.text)

# %%
ratings=[]
for i in driver.find_elements_by_xpath("//span[@class='ipl-rating-star__rating']"):
    ratings.append(i.text)

# %%
votes=[]
for i in driver.find_elements_by_xpath("//span[@name='nv']"):
    votes.append(i.text)

# %%
a=({'Name':name,
'Year_span':span,
'Genre':genre,
'Run_time':time,
'Ratings':ratings,
'Votes':votes})

# %%
df=pd.DataFrame.from_dict(a,orient='index')
df= df.transpose()

# %%
df.head(10)
# Out:
#                                      Name    Year_span  \
# 0          1. Game of Thrones (2011–2019)  (2011–2019)
# 1             2. Stranger Things (2016– )     (2016– )
# 2         3. The Walking Dead (2010–2022)  (2010–2022)
# 3           4. 13 Reasons Why (2017–2020)  (2017–2020)
# 4                  5. The 100 (2014–2020)  (2014–2020)
# 5  6. Orange Is the New Black (2013–2019)  (2013–2019)
# 6                   7. Riverdale (2017– )     (2017– )
# 7              8. Grey's Anatomy (2005– )     (2005– )
# 8                   9. The Flash (2014– )     (2014– )
# 9                   10. Arrow (2012–2020)  (2012–2020)
#
#                       Genre Run_time Ratings      Votes
# 0  Action, Adventure, Drama   57 min     9.2  1,839,817
# 1    Drama, Fantasy, Horror   51 min            878,271
# 2   Drama, Horror, Thriller   44 min    Rate    881,385
# 3  Drama, Mystery, Thriller   60 min            264,691
# 4    Drama, Mystery, Sci-Fi   43 min            226,131
# ...

# %% [markdown]
# # 10.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# %%
url = "https://archive.ics.uci.edu/"
driver.get(url)

# %%
dataset_click = driver.find_element_by_xpath('/html/body/table[1]/tbody/tr/td[2]/span[2]/a/font/b')
dataset_click.click()

# %%
dataset_name = []
for i in driver.find_elements_by_xpath('//table[@cellpadding = "3"]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]'):
    dataset_name.append(i.text)

# %%
data_type = []
for i in driver.find_elements_by_xpath('//table[@cellpadding = "3"]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]'):
    data_type.append(i.text)

# %%
task = []
for i in driver.find_elements_by_xpath('//table[@cellpadding = "3"]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]'):
    task.append(i.text)

# %%
atype = []
for i in driver.find_elements_by_xpath('//table[@cellpadding = "3"]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]'):
    atype.append(i.text)

# %%
instance = []
for i in driver.find_elements_by_xpath('//table[@cellpadding = "3"]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]'):
    instance.append(i.text)

# %%
attribute = []
for i in driver.find_elements_by_xpath('//table[@cellpadding = "3"]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]'):
    attribute.append(i.text)

# %%
year = []
for i in driver.find_elements_by_xpath('//table[@cellpadding = "3"]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]'):
    year.append(i.text)

# %%
df=pd.DataFrame({'Dataset_name':dataset_name, 'Data_type':data_type, 'Task':task, 'Attribute_type':atype, 'no_of instance':instance, 'no_of_attribute':attribute, 'Year':year})

# %%
df
# Out:
#                            Dataset_name      Data_type                  Task  \
# 0                                  Name     Data Types          Default Task
# 1                               Abalone  Multivariate        Classification
# 2                                 Adult  Multivariate        Classification
# 3                             Annealing  Multivariate        Classification
# 4          Anonymous Microsoft Web Data                 Recommender-Systems
# ..                                  ...            ...                   ...
# 584    in-vehicle coupon recommendation  Multivariate        Classification
# 585                 Gait Classification  Multivariate        Classification
# 586           Wikipedia Math Essentials   Time-Series            Regression
# 587           Wikipedia Math Essentials   Time-Series            Regression
# 588        Synchronous Machine Data Set  Multivariate            Regression
#
# ...
